# %%
import sys

# %%
# !{sys.executable} mtum_train.py
# Out:
# Loading training data ...
# Treatment priors: {0: 0.5026597218374245, 1: 0.08209674738183631, 3: 0.08217432260209453, 4: 0.08313293068099961, 5: 0.08539923532997173, 6: 0.08322158807558043, 7: 0.08131545409209287}
# Training CatBoost MultiClass ...
# Learning rate set to 0.185255
# 0:	learn: 2.6215827	total: 926ms	remaining: 7m 42s
# 100:	learn: 2.2017875	total: 1m 55s	remaining: 7m 34s
# 200:	learn: 1.8436936	total: 4m 1s	remaining: 5m 59s
# 300:	learn: 1.6293821	total: 6m 8s	remaining: 4m 3s
# 400:	learn: 1.4771672	total: 8m 25s	remaining: 2m 4s
# 499:	learn: 1.3743630	total: 10m 26s	remaining: 0us
# Training complete. Class order: ['no_reactivated_0' 'no_reactivated_1' 'no_reactivated_3'
#  'no_reactivated_4' 'no_reactivated_5' 'no_reactivated_6'
#  'no_reactivated_7' 'reactivated_0' 'reactivated_1' 'reactivated_3'
#  'reactivated_4' 'reactivated_5' 'reactivated_6' 'reactivated_7']
# Feature count: 24
#                   precision    recall  f1-score   support
#
# ...

# %%
# !{sys.executable} mtum_evaluate.py
# Out:
# Loading training data ...
# Total rows: 180,470
#
# Counts per treatment arm:
# treatment
# 0    90715
# 1    14816
# 3    14830
# 4    15003
# 5    15412
# 6    15019
# 7    14675
#
# Train: 126,329   Test: 54,141
#
# Train counts per arm:
# treatment
# 0    63501
# 1    10371
# 3    10381
# 4    10502
# 5    10788
# 6    10513
# 7    10273
#
# Test counts per arm:
# treatment
# 0    27214
# 1     4445
# 3     4449
# 4     4501
# 5     4624
# 6     4506
# 7     4402
#
# Reactivation rate per arm (test):
# treatment
# 0    0.0207
# 1    0.0216
# 3    0.0247
# 4    0.0236
# 5    0.0236
# 6    0.0253
# 7    0.0223
#
# Training CatBoost MultiClass on 70% train split ...
# Learning rate set to 0.181916
# 0:	learn: 2.6081539	total: 649ms	remaining: 5m 23s
# 100:	learn: 2.1114132	total: 1m 12s	remaining: 4m 46s
# 200:	learn: 1.7107838	total: 2m 32s	remaining: 3m 47s
# 300:	learn: 1.4777197	total: 3m 53s	remaining: 2m 34s
# 400:	learn: 1.3417505	total: 5m 14s	remaining: 1m 17s
# ...

# %%
# !{sys.executable} mtum_score.py
# Out:
# Recomputing treatment priors from training data ...
# Treatment priors: {0: 0.5026597218374245, 1: 0.08209674738183631, 3: 0.08217432260209453, 4: 0.08313293068099961, 5: 0.08539923532997173, 6: 0.08322158807558043, 7: 0.08131545409209287}
# Loading trained model from Models\mtum_phase_2_catboost.cbm ...
# Class order: ['no_reactivated_0' 'no_reactivated_1' 'no_reactivated_3'
#  'no_reactivated_4' 'no_reactivated_5' 'no_reactivated_6'
#  'no_reactivated_7' 'reactivated_0' 'reactivated_1' 'reactivated_3'
#  'reactivated_4' 'reactivated_5' 'reactivated_6' 'reactivated_7']
# Loading deployment data ...
# Deployment cohort size: 564774
# Scoring deployment cohort ...
# Assignment rows: 282387 -> Deployement_dataset\deployement
# Mean optimal CATE: 0.869070
#
# RFM per incentive:
#                                  recency        monetary_value             n
#                                     mean median           mean median
# original_incentive_name
# ...
